# %% [markdown]
# # Team Silkroad
#
# ---
#
# The time has come to take our game underground.  Our company is being hired to provide insights and metrics for a government contract entity that can potentially evaluate emerging crypto-currencies.  Understanding these markets will help ongoing and future investigations of illegal underground marketplaces operating from [darknets](https://en.wikipedia.org/wiki/Darknet_market).
#
# The general goals are:
#
# - Invent some quality metric(s) to help us measure these currencies
# - Project any kind of lifetime of given market
# - Volatility
# - Impact of "mine-ability" on any of the above
#
# ### End with addressing this one question:  If one were to open or operate an illegal marketplace, which currency choice is best?
#
# The point of this exercise is to assess the viability of this dataset to answer our questions of interest.  If the dataset cannot address these questions effectively:
#
#  - Why not? What are the limitations?
#  - What other data would we need?
#  - What questions could this dataset address, if not the original intended asks for this project?
#
# Please address the above in your presentation.  Framing is key!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

currencies = pd.read_csv("./datasets/currencies_and_assets.csv")
exchanges = pd.read_csv("./datasets/exchanges_and_markets.csv")

# %%
# clean currencies 
def clean_numeric_cell(value):
    if type(value) == str:
        value = value.replace('$','').replace(',','').replace('%','').replace(' ','') # remove $ from prices to facilitate sorting
    try:
        value = float(value)
    except:
        value = np.NaN # convert invalid values to NaN
    return value

numeric_columns_currencies = ['Price', 'Market Capitalization', "Volume (17 Oct. '14)", "Available suppy"]
for column_name in numeric_columns_currencies:
    currencies[column_name] = currencies[column_name].apply(clean_numeric_cell)

currencies.info() # ensure numeric_columns are in float type 
currencies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533 entries, 0 to 532
# Data columns (total 12 columns):
# Name                     533 non-null object
# Image                    533 non-null object
# Type                     533 non-null object
# Status                   380 non-null object
# Symbol                   505 non-null object
# Platform                 28 non-null object
# Market Capitalization    485 non-null float64
# Price                    533 non-null float64
# Available suppy          485 non-null float64
# Volume (17 Oct. '14)     373 non-null float64
# More Information         519 non-null object
# Profile                  533 non-null object
# dtypes: float64(4), object(8)
# memory usage: 50.0+ KB
#       Name                                              Image            Type  \
# 0  RosCoin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 1  365Coin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 2  DarkFox  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 3  66 Coin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 4    Acoin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
#
#     Status Symbol Platform  Market Capitalization  Price  Available suppy  \
# 0      NaN    ROS      NaN                39669.0   0.00       75737672.0
# 1  Minable    365      NaN                 2714.0  19.42            140.0
# 2      NaN    DRX      NaN                  304.0   0.00         576390.0
# 3  Minable     66      NaN                    NaN  30.59              NaN
# 4  Minable  ACOIN      NaN                 3168.0   0.02         150530.0
#
#    Volume (17 Oct. '14)                          More Information  \
# 0               14995.0  http://216.231.132.86:2000/chain/Roscoin
# 1                   NaN                       http://365coin.net/
# 2                   NaN       http://62.113.238.105/chain/darkfox
# 3                   NaN                        http://66coin.org/
# 4                  71.0                        http://a-coin.info
#
#                                          Profile
# 0  https://coinmarketcap.com/currencies/roscoin/
# 1  https://coinmarketcap.com/currencies/365coin/
# 2  https://coinmarketcap.com/currencies/darkfox/
# 3  https://coinmarketcap.com/currencies/66-coin/
# 4    https://coinmarketcap.com/currencies/acoin/

# %%
# clean exchanges 
numeric_columns_exchanges = ['Price',"Volume (17 Oct. '14)",'Volume (%)','Percentage of Market']
for column_name in numeric_columns_exchanges:
    exchanges[column_name] = exchanges[column_name].apply(clean_numeric_cell)

exchanges.info()
exchanges.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 7 columns):
# ID                      1330 non-null object
# Traded Currencies       1330 non-null object
# Percentage of Market    1320 non-null float64
# Source                  1330 non-null object
# Volume (17 Oct. '14)    1330 non-null float64
# Price                   1330 non-null float64
# Volume (%)              1330 non-null float64
# dtypes: float64(4), object(3)
# memory usage: 72.8+ KB
#                               ID    Traded Currencies  Percentage of Market  \
# 0    Cryptsy - 42 Coin / Bitcoin     42 Coin, Bitcoin                   0.0
# 1   SwissCEX - 42 Coin / Bitcoin     42 Coin, Bitcoin                   0.0
# 2     Cryptsy - 42 Coin / Ripple      42 Coin, Ripple                   0.0
# 3  Coin-Swap - 66 Coin / Bitcoin     66 Coin, Bitcoin                   0.0
# 4   C-CEX - Abundance2 / Bitcoin  Abundance2, Bitcoin                   0.0
#
#       Source  Volume (17 Oct. '14)    Price  Volume (%)
# 0    Cryptsy                 673.0  2330.00       96.47
# 1   SwissCEX                   0.0  2016.00        0.00
# 2    Cryptsy                  25.0  2151.00        3.53
# 3  Coin-Swap                   0.0    30.55      100.00
# 4      C-CEX                  36.0     0.02      100.00

# %%
# split exchanges' traded currencies to 2 columns
exchanges['Traded Currency 1'] = exchanges['Traded Currencies'].apply(lambda x: x.split(',')[0])
exchanges['Traded Currency 2'] = exchanges['Traded Currencies'].apply(lambda x: x.split(',')[1].strip())
exchanges.head()
# Out:
#                               ID    Traded Currencies  Percentage of Market  \
# 0    Cryptsy - 42 Coin / Bitcoin     42 Coin, Bitcoin                   0.0
# 1   SwissCEX - 42 Coin / Bitcoin     42 Coin, Bitcoin                   0.0
# 2     Cryptsy - 42 Coin / Ripple      42 Coin, Ripple                   0.0
# 3  Coin-Swap - 66 Coin / Bitcoin     66 Coin, Bitcoin                   0.0
# 4   C-CEX - Abundance2 / Bitcoin  Abundance2, Bitcoin                   0.0
#
#       Source  Volume (17 Oct. '14)    Price  Volume (%) Traded Currency 1  \
# 0    Cryptsy                 673.0  2330.00       96.47           42 Coin
# 1   SwissCEX                   0.0  2016.00        0.00           42 Coin
# 2    Cryptsy                  25.0  2151.00        3.53           42 Coin
# 3  Coin-Swap                   0.0    30.55      100.00           66 Coin
# 4      C-CEX                  36.0     0.02      100.00        Abundance2
#
#   Traded Currency 2
# 0           Bitcoin
# 1           Bitcoin
# 2            Ripple
# 3           Bitcoin
# 4           Bitcoin

# %%
currencies.head()
# Out:
#       Name                                              Image            Type  \
# 0  RosCoin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 1  365Coin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 2  DarkFox  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 3  66 Coin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
# 4    Acoin  https://coinmarketcap.com/static/img/coins/16x...  Cryptocurrency
#
#     Status Symbol Platform  Market Capitalization  Price  Available suppy  \
# 0      NaN    ROS      NaN                39669.0   0.00       75737672.0
# 1  Minable    365      NaN                 2714.0  19.42            140.0
# 2      NaN    DRX      NaN                  304.0   0.00         576390.0
# 3  Minable     66      NaN                    NaN  30.59              NaN
# 4  Minable  ACOIN      NaN                 3168.0   0.02         150530.0
#
#    Volume (17 Oct. '14)                          More Information  \
# 0               14995.0  http://216.231.132.86:2000/chain/Roscoin
# 1                   NaN                       http://365coin.net/
# 2                   NaN       http://62.113.238.105/chain/darkfox
# 3                   NaN                        http://66coin.org/
# 4                  71.0                        http://a-coin.info
#
#                                          Profile
# 0  https://coinmarketcap.com/currencies/roscoin/
# 1  https://coinmarketcap.com/currencies/365coin/
# 2  https://coinmarketcap.com/currencies/darkfox/
# 3  https://coinmarketcap.com/currencies/66-coin/
# 4    https://coinmarketcap.com/currencies/acoin/

# %%
currencies.sort_values('Market Capitalization',ascending=False).head()
# Out:
#            Name                                              Image  \
# 431     Bitcoin  https://coinmarketcap.com/static/img/coins/16x...
# 508      Ripple  https://coinmarketcap.com/static/img/coins/16x...
# 504    Litecoin  https://coinmarketcap.com/static/img/coins/16x...
# 24   BitSharesX  https://coinmarketcap.com/static/img/coins/16x...
# 92     Dogecoin  https://coinmarketcap.com/static/img/coins/16x...
#
#                Type   Status Symbol Platform  Market Capitalization   Price  \
# 431  Cryptocurrency  Minable    BTC      NaN           5.120094e+09  382.31
# 508  Cryptocurrency      NaN    XRP      NaN           1.417435e+08    0.00
# 504  Cryptocurrency  Minable    LTC      NaN           1.315278e+08    3.99
# 24   Cryptocurrency      NaN   BTSX      NaN           5.267633e+07    0.03
# 92   Cryptocurrency  Minable   DOGE      NaN           2.451555e+07    0.00
#
#      Available suppy  Volume (17 Oct. '14)              More Information  \
# 431     1.339245e+07            27154900.0          https://bitcoin.org/
# 508     2.898925e+10              256918.0  https://ripple.com/currency/
# 504     3.297610e+07             4409110.0          https://litecoin.org
# 24      1.999884e+09              286116.0       http://bitshares-x.info
# 92      9.430616e+10              275071.0          http://dogecoin.com/
#
#                                                Profile
# 431      https://coinmarketcap.com/currencies/bitcoin/
# 508       https://coinmarketcap.com/currencies/ripple/
# 504     https://coinmarketcap.com/currencies/litecoin/
# 24   https://coinmarketcap.com/currencies/bitshares-x/
# 92      https://coinmarketcap.com/currencies/dogecoin/

# %%
currencies['check']=currencies["Market Capitalization"]/currencies['Price']

# %%
sns.heatmap(currencies.corr(),annot=True)
plt.show()

# %%
# which currencies can trade for the most number of currencies? - ensure i can sell easily
exchanges.head()

from collections import defaultdict
exchangeable_currency_field_analysis = defaultdict(list)

for k, v in exchanges['Traded Currency 1'].items():
    exchangeable_currency_field_analysis[v].append(exchanges['Traded Currency 2'][k])

for k, v in exchanges['Traded Currency 2'].items():
    exchangeable_currency_field_analysis[v].append(exchanges['Traded Currency 1'][k])
    
exchangable_coins_unique = {k:list(set(v)) for (k,v) in exchangeable_currency_field_analysis.items()}
exchangable_coins_count = {k:len(v) for (k,v) in exchangable_coins_unique.items()}
top_currencies_by_currency_count = sorted(exchangable_coins_count, key=exchangable_coins_count.get, reverse=True)[:5]
print('top_currencies_by_currency_count:',top_currencies_by_currency_count)
for key in top_currencies_by_currency_count:
    print(key,':',exchangable_coins_count[key],exchangable_coins_unique[key])
# Out:
# top_currencies_by_currency_count: ['Bitcoin', 'Litecoin', 'Chinese Yuan', 'Dogecoin', 'Ripple']
# Bitcoin : 457 ['AppleByte', 'Titcoin', 'ApexCoin', 'VaultCoin', 'Bitstar', 'Magicoin', 'Aricoin', 'Ethercoin', '66 Coin', 'Bitmark', 'Auroracoin', 'Fantomcoin', 'Ekrona', 'Altcoin', 'Quark', 'KlondikeCoin', 'CHCCoin', 'DigiByte', 'Techcoin', 'YellowCoin', 'BritCoin', 'Glyph', 'ReddCoin', 'eKita', 'XCurrency', 'VootCoin', 'DigitalPrice', 'Riecoin', 'TacoCoin', 'GamerholicCoin', 'TEKcoin', 'Silkcoin', 'Qora', 'AlphaCoin', 'CoolCoin', 'Scotcoin', 'Namecoin', 'Marscoin', 'Halcyon', 'NautilusCoin', 'Canadian Dollars', 'PotCoin', 'MammothCoin', 'Tomatocoin', 'Storjcoin X', 'CAIx', 'ImperialCoin', 'NanoToken', 'Russian Ruble', 'Axron', 'LTBcoin', 'CoCoCoin', 'Yacoin', 'YbCoin', 'BetaCoin', 'MGW', 'Vertcoin', 'Clams', 'PayzorCoin', 'ProsperCoin', 'DarkToken', 'DarkNote', 'Navajo', 'Dirac', 'SuperCoin', 'InkWayCoin', 'Minerals', 'SuperNET', 'Talkcoin', 'SambaCoin', 'WeAreSatoshi', 'Particle', 'GoldReserve', 'BBQCoin', 'NoirShares', 'NTX', 'ShibeCoin', 'OpenSourcecoin', 'FreshCoin', 'Vidio', 'Monocle', 'Krugercoin', 'Libertycoin', 'Sterlingcoin', 'Noirbits', 'Viacoin', 'CHNCoin', 'Motocoin', 'SSVCoin', 'ExclusiveCoin', 'StabilityShares', 'AsiaCoin', 'Catcoin', 'Rubycoin', 'Fractalcoin', 'Umbrella-LTC', 'XXXcoin', 'BattleCoin', 'WhiteCoin', 'OrangeCoin', 'GraniteCoin', 'FreeMarket', 'AimCoin', 'Diamond', 'Pesetacoin', 'Cryptographic Anomaly', 'CryptoEscudo', 'Flexiblecoin', 'BlueCoin', 'BeaverCoin', 'BlackToken', 'BCT Coin', 'BlackCoin', 'KashmirCoin', 'Stealthcoin', 'Maieuticoin', 'Electron', 'WankCoin', 'Sync', 'BitSwift', 'Bitleu', 'Cinni', 'VolatilityCoin', 'Bitgem', 'OPECCoin', 'EZCoin', 'NXTInspect', 'HyperStake', 'Solcoin', 'US Dollar', 'Quarkbar', 'PeleCoin', 'Xuro', 'Carboncoin', 'ShieldCoin', 'Philosopher Stones', 'ESportsCoin', 'Darkcoin', 'MidasCoin', 'ProzCoin', 'DopeCoin', 'Skynet', 'VexCoin', 'GlobalCoin', 'MultiWalletCoin', 'eUtopium', 'CleanWaterCoin', 'Bitcoin Plus', 'SHACoin', 'SysCoin', 'Spots', 'Monero', 'Coinomat', 'GameLeagueCoin', 'Litecoin', 'ORObit', 'Bytecoin', 'Gridcoin', 'Deepcoin', 'CoffeeCoin', 'Nxttycoin', 'XCloudcoin', 'SmartCoin', 'jl777hodl', 'Extremecoin', 'IOCoin', 'Deutsche eMark', 'KoreCoin', 'Latium', 'Noahcoin', 'NeosCoin', 'Dogecoin', 'Gnosis', 'Solecoin', 'Functioncoin', 'Execoin', 'Infinitecoin', 'UnbreakableCoin', 'Dogeparty', 'Saturn2Coin', 'NewYorkCoin', 'Razor', 'MemoryCoin', 'AurumCoin', 'Piggycoin', 'Lycancoin', 'Aliencoin', 'SocialxBot', 'DarkCash', 'FoldingCoin', 'QuazarCoin', 'BellaCoin', 'RonPaulCoin', 'Electronic Gulden', 'Terracoin', 'Karmacoin', 'StarCoin', 'ShadowCash', 'Trollcoin', 'BurnerCoin', 'Nimbus', 'Ringo', 'USDe', 'Neutrino', 'Donationcoin', 'Aerocoin', 'Shinycoin', 'Quatloo', 'Opal', 'GlobalBoost-Y', 'GroestlCoin', 'CAPTcoin', 'Cryptogenic Bullion', 'UtilityCoin', 'RipoffCoin', 'Neocoin', 'HoboNickels', 'CraftCoin', 'Fibre', 'RotoCoin', 'Wavecoin', 'MtGoxCoin', 'TraderCoin', 'Megacoin', 'Aiden', 'Viking Coin', 'Myriadcoin', 'Guncoin', 'MonetaVerde', 'GoldCoin', 'LiteBar', 'GreenBacks', 'Murraycoin', 'XCash', 'WhistleCoin', 'Kryptkoin', '42 Coin', 'Benjamins', 'Lion', 'LegendaryCoin', 'Instant', 'VirtualMiningCoin', 'Coin2.1', 'TorCoin', 'Cannacoin', 'Truckcoin', 'RosCoin', 'KeyCoin', 'ShadeCoin', 'Peercoin', 'Pesa', 'British Pound', 'PLNcoin', 'NetCoin', 'TrustPlus', 'Orbitcoin', 'USBCoin', 'ClearingHouse', 'ElephantCoin', 'Marinecoin', 'Mincoin', 'Bottlecaps', 'Joincoin', 'LitecoinDark', 'Guldencoin', 'BitBar', 'CryptCoin', 'CryptoBuk', 'Conspiracycoin', 'BitcoinDark', 'Burst', 'Startcoin', 'OrthoCoin', 'Darkpeer', 'Checkcoin', 'Firecoin', 'Anoncoin', 'NuBits', 'Denarius', 'Coin', 'SecureCoin', 'Feathercoin', 'Aegis', 'Junkcoin', 'OctoCoin', 'Stellar', 'Phoenixcoin', 'RescueCoin', 'BanxShares', 'ZcCoin', 'Argentum', 'ConcealCoin', 'TopCoin', 'CommunityCoin', 'Boolberry', 'PinkCoin', 'ZimStake', 'BigBullion', 'CacheCoin', 'Nyancoin', 'New Universal Dollar', 'NeXT Horizon', 'Chinese Yuan', 'Nas', 'BitShares PTS', 'Pandacoin', 'Acoin', 'Mintcoin', 'Nxt', 'CasinoCoin', 'Ske ...
# Litecoin : 89 ['GoldCoin', 'Wincoin', 'Sexcoin', 'Digitalcoin', 'Tickets', 'Mooncoin', 'Penguincoin', 'ContinuumCoin', 'EarthCoin', 'RedCoin', 'FedoraCoin', 'GameCoin', 'AsicCoin', 'EZCoin', 'Auroracoin', 'Kittehcoin', 'US Dollar', 'CloakCoin', 'Quark', 'RabbitCoin', 'Devcoin', 'Peercoin', 'LeafCoin', 'Darkcoin', 'NetCoin', 'Glyph', 'FlorinCoin', 'ElephantCoin', 'FlappyCoin', 'ReddCoin', 'XCurrency', 'CageCoin', 'Bongger', 'Guerillacoin', 'CryptCoin', 'HTMLCOIN', 'KimDotCoin', 'FAILCoin', 'BitCentavo', 'TeslaCoin', 'Franko', 'Heisenberg', 'Emucoin', 'Anoncoin', 'Colossuscoin', 'Photon', 'Feathercoin', 'ImperialCoin', 'Phoenixcoin', 'Yacoin', 'Vertcoin', 'Infinitecoin', 'SuperCoin', 'NewYorkCoin', 'Razor', 'WeAreSatoshi', 'Memecoin', 'ECCoin', 'Zetacoin', 'Kumacoin', 'Nyancoin', 'Dimecoin', 'Chinese Yuan', 'CorgiCoin', 'CHNCoin', 'Bitcoin', 'LottoCoin', 'NFDCoin', 'Pandacoin', 'BatCoin', 'Karmacoin', 'Doubloons', 'Trollcoin', 'VeriCoin', 'Fastcoin', 'XenCoin', 'CaliforniaCoin', 'StableCoin', 'BlazeCoin', 'Cryptogenic Bullion', 'MaxCoin', 'MonaCoin', 'WorldCoin', 'UltraCoin', 'Primecoin', 'Megacoin', 'Grain', 'Zeitcoin', 'BlackCoin']
# Chinese Yuan : 51 ['YbCoin', 'Freicoin', 'ZcCoin', 'TagCoin', 'Dogecoin', 'BilShares', 'VeriCoin', 'Vertcoin', 'Digitalcoin', 'Tickets', 'Infinitecoin', 'BoostCoin', 'Riecoin', 'Applecoin', 'Monero', 'BitBar', 'Litecoin', 'RedCoin', 'FedoraCoin', 'SuperNET', 'MemoryCoin', 'MaxCoin', 'Zetacoin', 'BBQCoin', 'Counterparty', 'Ripple', 'Datacoin', 'Nxttycoin', 'WorldCoin', 'SecureCoin', 'Anoncoin', 'Primecoin', 'Feathercoin', 'Quark', 'Devcoin', 'CHNCoin', 'Megacoin', 'Bitcoin', 'Peercoin', 'UnionCoin', 'BitShares PTS', 'Extremecoin', 'BitCNY', 'BitSharesX', 'Stellar', 'Darkcoin', 'Mintcoin', 'Nxt', 'NetCoin', 'BlackCoin', 'Yacoin']
# Dogecoin : 39 ['Guncoin', 'Titcoin', 'Trollcoin', 'Old Russian Ruble', 'Canada eCoin', 'FlappyCoin', 'ReddCoin', 'CageCoin', 'Mooncoin', 'Penguincoin', 'TacoCoin', 'Guldencoin', 'CaliforniaCoin', 'Copperlark', 'BlazeCoin', 'NewYorkCoin', 'FedoraCoin', 'HTMLCOIN', 'FAILCoin', 'Aliencoin', 'Scotcoin', 'PotCoin', 'Nyancoin', 'Pennies', 'Heisenberg', 'Emucoin', 'Chinese Yuan', 'CorgiCoin', 'Sterlingcoin', 'LemurCoin', 'Bitcoin', 'BeaverCoin', 'ImperialCoin', 'Pandacoin', 'CannabisCoin', 'Mintcoin', 'Zeitcoin', 'BunnyCoin', 'Karmacoin']
# Ripple : 37 ['Ixcoin', 'TagCoin', 'Vertcoin', 'FlappyCoin', 'ReddCoin', '42 Coin', 'Mooncoin', 'Infinitecoin', 'Aerocoin', 'LitecoinDark', 'Unobtanium', 'EarthCoin', 'TEKcoin', 'HoboNickels', 'Aliencoin', 'Namecoin', 'BitcoinDark', 'Halcyon', 'PotCoin', 'WorldCoin', 'Auroracoin', 'CraigsCoin', 'Anoncoin', 'Chinese Yuan', 'Colossuscoin', 'Luckycoin', 'US Dollar', 'CloakCoin', 'Bitcoin', 'LeafCoin', 'CannabisCoin', 'Mintcoin', 'Zeitcoin', 'NetCoin', 'Phoenixcoin', 'Karmacoin', 'Japanese Yen']

# %%
# # which currencies can trade for the most number of platform? - ensure i can sell easily

from collections import defaultdict
source_field_analysis = defaultdict(list)

for k, v in exchanges['Traded Currency 1'].items():
    source_field_analysis[v].append(exchanges['Source'][k])

for k, v in exchanges['Traded Currency 2'].items():
    source_field_analysis[v].append(exchanges['Source'][k])
    
source_field_analysis_unique = {k:list(set(v)) for (k,v) in source_field_analysis.items()}
source_field_analysis_count = {k:len(v) for (k,v) in source_field_analysis_unique.items()}
top_source_field_analysis_count = sorted(source_field_analysis_count, key=source_field_analysis_count.get, reverse=True)[:5]
print('top_currencies_by_currency_count:',top_source_field_analysis_count)
for key in top_source_field_analysis_count:
    print(key,':',source_field_analysis_count[key],source_field_analysis_unique[key])
# Out:
# top_currencies_by_currency_count: ['Bitcoin', 'Litecoin', 'Dogecoin', 'US Dollar', 'Nxt']
# Bitcoin : 45 ['Crypto-Trade', 'Bitfinex', 'BitcoinAverage', 'Kraken', 'AllCoin', 'Cryptsy', 'Cryptoine', 'Atomic Trade', 'Comkort', 'MasterXchange', 'useCryptos', 'Mastercoin DEX', 'Poloniex', 'AllCrypt', 'CCEDK', 'Vircurex', 'mcxNOW', 'CEX.IO', 'Coinbroker', 'BANX.IO', 'BTC', 'BX Thailand', 'Ripple Charts', 'Coin-Swap', 'Counterparty DEX', 'NIX-E', 'BTC-E', 'Justcoin', 'SwissCEX', 'Cryptex', 'C-CEX', 'DGEX', 'Ask Coin', 'Bitorado', 'Coins-E', 'Mona Tore', 'Bittrex', 'HitBTC', 'UpBit', 'Bleutrade', 'Ybex', 'Cryptonit', 'BTER', 'Melotic', 'X-BT']
# Litecoin : 19 ['Crypto-Trade', 'Bitfinex', 'AllCoin', 'Cryptsy', 'Atomic Trade', 'Comkort', 'useCryptos', 'OkCoin Intl.', 'BTC', 'BTC-E', 'SwissCEX', 'Cryptex', 'Ask Coin', 'Mona Tore', 'BTC China', 'HitBTC', 'Bittrex', 'Bleutrade', 'BTER']
# Dogecoin : 14 ['SwissCEX', 'BTC', 'Kraken', 'HitBTC', 'Bittrex', 'AllCoin', 'UpBit', 'Cryptsy', 'Comkort', 'Bleutrade', 'Poloniex', 'Coin-Swap', 'BTER', 'Exmo']
# US Dollar : 12 ['Crypto-Trade', 'Bitfinex', 'BitcoinAverage', 'HitBTC', 'Ripple Charts', 'UpBit', 'Cryptsy', 'useCryptos', 'OkCoin Intl.', 'BTER', 'NIX-E', 'BTC-E']
# Nxt : 9 ['BTC', 'Nxt Asset Exchange', 'Bittrex', 'HitBTC', 'Cryptsy', 'DGEX', 'Poloniex', 'CCEDK', 'BTER']

# %%
exchanges.plot.bar(x='Traded Currency 1', y= 'Price')

# %%
pd.DataFrame({x: [v] for x, v in exchangable_coins_count.items()}, axi)
# Out:
#    42 Coin  66 Coin  Abundance2  ach  Acoin  Aegis  Aerocoin  AidBit  Aiden  \
# 0        2        1           1    1      1      1         2       1      1
#
#    AimCoin      ...       Zetacoin  ZimStake  Chinese Yuan  British Pound  \
# 0        1      ...              4         1            51              7
#
#    Canadian Dollars  Euro  Russian Ruble  US Dollar  Old Russian Ruble  \
# 0                12     6              2         19                  2
#
#    Japanese Yen
# 0             1
#
# [1 rows x 513 columns]
